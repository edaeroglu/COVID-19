# %%
import numpy as np
import pandas as pd
import os

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# > ***What is known about adaptations (mutations) of the virus***

# %%
df1 = pd.read_csv('/kaggle/input/CORD-19-research-challenge/Kaggle/target_tables/4_models_and_open_questions/What is known about adaptations (mutations) of the virus_.csv')

# %%
df1.shape
# Out:
# (19, 9)

# %%
df1.head()
# Out:
#    Unnamed: 0        Date                                              Study  \
# 0           0  2020-04-20  SARS-coronavirus-2 replication in Vero E6 cell...
# 1           1  2020-04-10  Remdesivir and SARS-CoV-2: Structural requirem...
# 2           2  2020-04-07  Translational adaptation of human viruses to t...
# 3           3  2020-03-31  Re-insights into origin and adaptation of SARS...
# 4           4  2020-03-30  A Genomic Survey of SARS-CoV-2 Reveals Multipl...
#
#                                         Study Link             Journal  \
# 0        https://doi.org/10.1101/2020.04.20.049924             bioRxiv
# 1  https://doi.org/10.1016/j.antiviral.2020.104793  Antiviral Research
# 2        https://doi.org/10.1101/2020.04.06.027557             bioRxiv
# 3        https://doi.org/10.1101/2020.03.30.015685             bioRxiv
# 4      https://doi.org/10.1101/2020.03.27.20044925             medRxiv
#
#                                            Method  \
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Study', 'Study Link', 'Journal', 'Method',
#        'Result', 'Measure of Evidence', 'Added on'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           19 non-null     int64
#  1   Date                 19 non-null     object
#  2   Study                19 non-null     object
#  3   Study Link           19 non-null     object
#  4   Journal              19 non-null     object
#  5   Method               18 non-null     object
#  6   Result               19 non-null     object
#  7   Measure of Evidence  19 non-null     object
#  8   Added on             19 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 1.5+ KB

# %%
df1.describe().T
# Out:
#             count  mean       std  min  25%  50%   75%   max
# Unnamed: 0   19.0   9.0  5.627314  0.0  4.5  9.0  13.5  18.0

# %%
df1['Journal'].value_counts()
# Out:
# Journal
# bioRxiv                                10
# medRxiv                                 2
# Antiviral Research                      1
# Clinical Microbiology and Infection     1
# EXCLI J                                 1
# Int J Biol Sci                          1
# Infection, Genetics and Evolution       1
# Clinical Infectious Diseases            1
# MDPI Healthcare                         1
# Name: count, dtype: int64

# %%
df1['Method'].value_counts()
# Out:
# Method
# Genomic Analysis                                  7
# Phylogenetics                                     2
# Genomic Analysis (tRNA quantification)            1
# Genomic Analysis (Structure Homology Modeling)    1
# Direct RNA sequencing/Mass spectrometry           1
# Genomic analysis/protein modeling                 1
# Proteomics                                        1
# qPCR/Genomic Analysis                             1
# Sequencing of bronchoalveolar lavage fluid        1
# Comparative Genomic Analysis                      1
# Combination - chest CT, RT-PCR, multi-plex PCR    1
# Name: count, dtype: int64

# %%
df1['Measure of Evidence'].value_counts()
# Out:
# Measure of Evidence
# -               12
# patients: 53     2
# patients: 29     1
# patients: 6      1
# patients: 3      1
# patients: 8      1
# patients: 27     1
# Name: count, dtype: int64

# %%
import matplotlib.pylab as plt
df1.hist(bins=50, figsize=(20,15))
plt.show()

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0             0
# Date                   0
# Study                  0
# Study Link             0
# Journal                0
# Method                 1
# Result                 0
# Measure of Evidence    0
# Added on               0
# dtype: int64

# %%
import missingno as msno 
msno.bar(df1)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.catplot(x="Journal",kind="count",data=df1, palette = "Set3", height=5, aspect=4)

# %%
sns.catplot(x="Method",kind="count",data=df1, palette = "Set3", height=5, aspect=7)

# %%
sns.catplot(x="Measure of Evidence",kind="count",data=df1, palette = "Set3", height=5, aspect=3)

# %% [markdown]
# > ***Diagnosing SARS-COV-2 with antibodies***

# %%
df2 = pd.read_csv('/kaggle/input/CORD-19-research-challenge/Kaggle/target_tables/6_diagnostics/Diagnosing SARS-COV-2 with antibodies.csv')

# %%
df2.shape
# Out:
# (34, 12)

# %%
df2.head()
# Out:
#    Unnamed: 0        Date                                              Study  \
# 0           0  2020-04-10  Evaluation of nine commercial SARS-CoV-2 immun...
# 1           1  2020-04-10  Evaluation of nine commercial SARS-CoV-2 immun...
# 2           2  2020-04-10  Evaluation of nine commercial SARS-CoV-2 immun...
# 3           3  2020-04-10  Evaluation of nine commercial SARS-CoV-2 immun...
# 4           4  2020-03-24  Diagnosing COVID-19: The Disease and Tools for...
#
#                                           Study Link  \
# 0  https://www.medrxiv.org/content/10.1101/2020.0...
# 1  https://www.medrxiv.org/content/10.1101/2020.0...
# 2  https://www.medrxiv.org/content/10.1101/2020.0...
# 3  https://www.medrxiv.org/content/10.1101/2020.0...
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
#
#                      Journal            Study Type  \
# 0                    medRxiv  Retrospective Cohort
# 1                    medRxiv  Retrospective Cohort
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Study', 'Study Link', 'Journal', 'Study Type',
#        'Detection Method', 'Sample Size', 'Measure of Testing Accuracy',
#        'Speed of assay', 'FDA approval (Y/N)', 'Added on'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   34 non-null     int64
#  1   Date                         34 non-null     object
#  2   Study                        34 non-null     object
#  3   Study Link                   34 non-null     object
#  4   Journal                      34 non-null     object
#  5   Study Type                   34 non-null     object
#  6   Detection Method             34 non-null     object
#  7   Sample Size                  34 non-null     object
#  8   Measure of Testing Accuracy  34 non-null     object
#  9   Speed of assay               31 non-null     object
#  10  FDA approval (Y/N)           32 non-null     object
#  11  Added on                     34 non-null     object
# dtypes: int64(1), object(11)
# memory usage: 3.3+ KB

# %%
df2.describe().T
# Out:
#             count  mean       std  min   25%   50%    75%   max
# Unnamed: 0   34.0  16.5  9.958246  0.0  8.25  16.5  24.75  33.0

# %%
df2['Journal'].value_counts()
# Out:
# Journal
# Emerging Microbes & Infections      8
# medRxiv                             7
# Journal of Clinical Microbiology    4
# Annals of Internal Medicine         3
# American Chemical Society           2
# Micromachines                       2
# Talanta                             1
# ChemRxiv                            1
# Journal of Clinical Medicine        1
# Journal of medical viriology        1
# Clinical Radiology                  1
# American society of microbiology    1
# Journal of Medical Virology         1
# Arch Pathol Lab Med                 1
# Name: count, dtype: int64

# %%
df2['Study Type'].value_counts()
# Out:
# Study Type
# Investigative Study     26
# Retrospective Cohort     4
# Review                   3
# Simulation Study         1
# Name: count, dtype: int64

# %%
df2['Detection Method'].value_counts()
# Out:
# Detection Method
# Serology                                                                  4
# Serology                                                                  4
# Serology (IgM & IgG Ab Eval)                                              2
# ELISA                                                                     2
# Wantai SARS-CoV-2 Total Antibody ELISA                                    1
# pan-HCoV                                                                  1
# Roche cobas SARS-CoV-2 assay                                              1
# rapid serological test Viva-Diag analyzingCOVID-19 associated-IgG/IgM.    1
# RT-PCR, Serology                                                          1
# Antigen Detection test                                                    1
# Rapid antigen test                                                        1
# VivaDiag COVID-19 IgM / IgG Rapid Test lateral flow immunoassay (LFIA)    1
# ...

# %%
df2['Speed of assay'].value_counts()
# Out:
# Speed of assay
# -                                  7
# 2 hrs                              4
# 1–8 h                              2
# 1+ hours                           2
# <15 minutes                        1
#  Roche 3 hr 45 min                 1
# >1 Hour NAAT (PCR)                 1
# >1 Hour                            1
# 15 mins                            1
# 7-11 days postexposure to virus    1
# >4 hrs                             1
# 15-30 min                          1
# 2–8 h                              1
# 1–7 days                           1
# 1–4 h                              1
# <30 min;                           1
# <1 Hour                            1
# RT-LAMP <1 hr; PCR 2-3 days;       1
# 5-45 minutes                       1
# 45 mins                            1
# Name: count, dtype: int64

# %%
df2['FDA approval (Y/N)'].value_counts()
# Out:
# FDA approval (Y/N)
# Y     26
# ?      3
# N      2
# Y      1
# Name: count, dtype: int64

# %%
import matplotlib.pylab as plt
df2.hist(bins=50, figsize=(20,15))
plt.show()

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0                     0
# Date                           0
# Study                          0
# Study Link                     0
# Journal                        0
# Study Type                     0
# Detection Method               0
# Sample Size                    0
# Measure of Testing Accuracy    0
# Speed of assay                 3
# FDA approval (Y/N)             2
# Added on                       0
# dtype: int64

# %%
import missingno as msno 
msno.bar(df2)
# Out:
# <Axes: >

# %%
sns.catplot(x="Journal",kind="count",data=df2, palette = "Set3", height=5, aspect=6)

# %%
sns.catplot(x="Study Type",kind="count",data=df2, palette = "Set3", height=5, aspect=3)

# %%
sns.catplot(x="Speed of assay",kind="count",data=df2, palette = "Set3", height=5, aspect=6)

# %%
sns.catplot(x="FDA approval (Y/N)",kind="count",data=df2, palette = "Set3", height=5, aspect=3)
